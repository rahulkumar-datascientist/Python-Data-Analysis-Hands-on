# %% [markdown]
# **Step 1: Write a function that can print out a board. Set up your board as a list, where each index 1-9 corresponds with a number on a number pad, so you get a 3 by 3 board representation.**

# %%
from IPython.display import clear_output

test_board = ['1','2','3','4','5','6','7','8','9']

def display_board(board):
    #clear_output()
    print('\n{0:^5}|{1:^5}|{2:^5}'.format(board[6],board[7],board[8]))
    print('{0:-^5}|{1:-^5}|{2:-^5}'.format(' ',' ',' '))
    print('{0:^5}|{1:^5}|{2:^5}'.format(board[3],board[4],board[5]))
    print('{0:-^5}|{0:-^5}|{0:-^5}'.format(''))
    print('{0:^5}|{1:^5}|{2:^5}'.format(board[0],board[1],board[2]))

# %%
#display_board(test_board)

# %% [markdown]
# **Step 2: Write a function that can take in a player input and assign their marker as 'X' or 'O'. Think about using *while* loops to continually ask until you get a correct answer.**

# %%
#def player_input():
 #   mark_X = 'X'
  #  mark_O = 'O'
   # inp = ''
    #
#    while True:
#        inp = input('\nPlayer 1, Enter your marker "X / O" : ').upper()
#        
#        if(inp == 'X'):
#            print('\nPlayer1 assigned the marker as: ',inp)
#           print('\nPlayer2, your marker is: ',mark_O)
#            break
#            
#        elif(inp == 'O'):
#            print('\nPlayer1 assigned the marker as: ',inp)
#            print('\nPlayer2, your marker is: ',mark_X)
#            break
#            
#        else:
#            print('\nPlease input the correct value !!')
#            
#            
#

# %%
#player_input()

# %%
def player_input1(first):
    marker = ''
    
    while not (marker == 'X' or marker == 'O'):
        marker = input('{} : Do you want to be X or O? '.format(first)).upper()
   

    if marker == 'X':
        return ('X', 'O')
    else:
        return ('O', 'X')

# %%
#player_input1('r')

# %% [markdown]
# **Step 3: Write a function that takes in the board list object, a marker ('X' or 'O'), and a desired position (number 1-9) and assigns it to the board.**

# %%
def place_marker(board,inp,pos):

    board[pos-1] = inp
    #display_board(board)

# %%
#place_marker(test_board,'X',5)

# %% [markdown]
# **Step 4: Write a function that takes in a board and a mark (X or O) and then checks to see if that mark has won.**

# %%
def win_check(board,inp):

    if(board[0] == board[1] == board[2] == inp):
        display_board(board)
        return 'Win'

    elif(board[0] == board[6] == board[3] == inp):
        display_board(board)
        return 'Win'

    elif(board[6] == board[7] == board[8] == inp):
        display_board(board)
        return 'Win'

    elif(board[2] == board[5] == board[8] == inp):
        display_board(board)
        return 'Win'

    elif(board[3] == board[4] == board[5] == inp):
        display_board(board)
        return 'Win'

    elif(board[7] == board[4] == board[1] == inp):
        display_board(board)
        return 'Win'

    elif(board[0] == board[4] == board[8] == inp):
        display_board(board)
        return 'Win'

    elif(board[6] == board[4] == board[2] == inp):
        display_board(board)
        return 'Win'

    else:
        display_board(board)
        return 'Continue'

# %%
#win_check(['x','1','2','3','x','x','6','7','x','9'],'x')

# %% [markdown]
# **Step 5: Write a function that uses the random module to randomly decide which player goes first. You may want to lookup random.randint() Return a string of which player went first.**

# %%
import random

def choose_first():
    if(random.randint(0,1) == 0):
        return 'Player 1'
    else:
        return 'Player 2'

# %%
#choose_first()

# %% [markdown]
# **Step 6: Write a function that returns a boolean indicating whether a space on the board is freely available.**

# %%
def space_check(board, position):
    
        if(board[position-1] == ' ' or board[position-1] == ''):
            return True
        else:
            return False

# %%
#space_check(['','2','3 ','4','5','6','7','8','9'],1)

# %% [markdown]
# **Step 7: Write a function that checks if the board is full and returns a boolean value. True if full, False otherwise.**

# %%
def full_board_check(board):
    item=0
    flag=0
    while (item<9):
        if((board[item]=='') or (board[item]== ' ')):
            flag=1
            break
        else:
            item+=1
                        
    if(flag==1):
        return False
    else:
        return True

# %%
#full_board_check(['1','2','3','r','5','6','7','8',' '])

# %%
#def full_board_check(board):
#    for i in range(1,10):
#        if (space_check(board, i) == False):
#            return False
#    return True

# %%
#full_board_check(['1','2','3','r','5','6','7','8',' '])

# %% [markdown]
# **Step 8: Write a function that asks for a player's next position (as a number 1-9) and then uses the function from step 6 to check if its a free position. If it is, then return the position for later use.**

# %%
def player_ch(board):
    posit = 0
    #flag = 0
    
    posit = int(input('Enter the position [1-9]: '))
    
    while True:#not (posit not in range(1,9)):
        
        if(posit not in range(1,10)):
                print('\nPosition out of range!!')
                posit = int(input('Enter the position [1-9]: '))
                continue
        
        while not(space_check(board, posit)):
                
          #  if(posit not in range(1,9)):
            #    print('Position out of range!!')
            #    posit = int(input('Enter the position [1-9]: '))
            #    continue
        
            #else:
                print('\nThe position is not empty!!')
                posit = int(input('Enter the position [1-9]: '))
            
        else:
            return posit

# %%
#player_ch(['1','2','3','4','5','','7','8','9'])

# %%
def player_choice(board):
    position = 0
    
    while position not in [1,2,3,4,5,6,7,8,9] or not space_check(board, position):
        position = int(input('Choose your next position: (1-9) '))
        
    return position

# %%
#player_choice(['1','2','3','4','5','','7','8','9'])

# %% [markdown]
# **Step 9: Write a function that asks the player if they want to play again and returns a boolean True if they do want to play again.**

# %%
def replay():
    choice = ''
    
    choice = input('Do you want to play again? [Y/N]: ').upper()
    
    while not (choice == 'Y' or choice == 'N'):
         choice = input('Enter correct choice: [Y/N]: ').upper()
        
    
    if(choice == 'Y'):
        return True
    
    else:
        return False

# %%
#replay()

# %% [markdown]
# **Step 10: Here comes the hard part! Use while loops and the functions you've made to run the game!**

# %%
#def driver():
    
    from IPython.display import clear_output
    import random

    first_chance = ''
    second_chance = ''
    p1_marker = ''
    p2_marker = ''
    order =()
    board = ['','','','','','','','','']
    rp = True
    pr = ''


    while(rp == True):
          
        print('Welcome to Tic Tac Toe!')

        first_chance = choose_first()

        if(first_chance == 'Player 1'):
            second_chance = 'Player 2'
        else:
            second_chance = 'Player 1'
    
        print('{}, you have the first chance'.format(first_chance))

        order = player_input1(first_chance)

        if(order[0] == 'X'):
            if(first_chance == 'Player 1'):
                p1_marker = 'X'
                p2_marker = 'O'
            else:
                p1_marker = 'X'
                p2_marker = 'O'
        
        else:
            if(first_chance == 'Player 1'):
                p1_marker = 'O'
                p2_marker = 'X'
            else:
                p1_marker = 'O'
                p2_marker = 'X'
       
    
        print('{} marker : '.format(first_chance),p1_marker)
        print('{} marker : '.format(second_chance),p2_marker)#

        print('The current board is :')
        display_board(board)

        for num in range(len(board)):
              
            if(num%2==0):
                print('{} Turn'.format(first_chance))
                if(full_board_check(board)== True):
                    print('Match draw !!')
                    if(replay() == False):
                        rp = False
                        return 'Thanks for playing! :)'
                    else:
                        driver()
                else:
                    pos_t = player_ch(board)
                    place_marker(board,p1_marker,pos_t)
                    if(win_check(board,p1_marker)== 'Win'):
                        print('{} won !!'.format(first_chance))
                        if(replay() == False):
                            rp = False
                            return 'Thanks for playing! :)'
                        else:
                            driver()
                        
                    
            else:
                print('{} Turn'.format(second_chance))
                if(full_board_check(board)== True):
                    print('Match draw !!')
                    if(replay() == False):
                        rp = False
                        return 'Thanks for playing! :)'
                    else:
                        driver()
                else:
                    pos_t = player_ch(board)
                    place_marker(board,p2_marker,pos_t)
                    if(win_check(board,p2_marker)== 'Win'):
                        print('{} won !!'.format(second_chance))
                        if(replay() == False):
                            rp = False
                            return 'Thanks for playing! :)'
                        else:
                            driver()
                            
        else:
            if(full_board_check(board)== True):
                print('Match draw !!')
                if(replay() == False):
                    rp = False
                    return 'Thanks for playing! :)'
                else:
                    driver()

# %%
#driver()
# Out:
# Welcome to Tic Tac Toe!
# Player 2, you have the first chance
# Player 2 : Do you want to be X or O? x
# Player 2 marker :  X
# Player 1 marker :  O
# The current board is :
#
#      |     |
# -- --|-- --|-- --
#      |     |
# -----|-----|-----
#      |     |
# Player 2 Turn
# Enter the position [1-9]: 5
#
#      |     |
# -- --|-- --|-- --
#      |  X  |
# -----|-----|-----
#      |     |
# Player 1 Turn
# Enter the position [1-9]: 7
#
#   O  |     |
# -- --|-- --|-- --
#      |  X  |
# -----|-----|-----
#      |     |
# Player 2 Turn
# Enter the position [1-9]: 3
#
#   O  |     |
# -- --|-- --|-- --
#      |  X  |
# -----|-----|-----
#      |     |  X
# Player 1 Turn
# Enter the position [1-9]: 8
#
#   O  |  O  |
# -- --|-- --|-- --
#      |  X  |
# -----|-----|-----
#      |     |  X
# Player 2 Turn
# Enter the position [1-9]: 9
#
#   O  |  O  |  X
# -- --|-- --|-- --
#      |  X  |
# -----|-----|-----
#      |     |  X
# Player 1 Turn
# Enter the position [1-9]: 4
#
# ...

# %%
def driver1():
    
    from IPython.display import clear_output
    import random

    first_chance = ''
    second_chance = ''
    p1_marker = ''
    p2_marker = ''
    order =()
    board = ['','','','','','','','','']
    rp = True
    pr = ''

    while(rp == True):
    
        print('Welcome to Tic Tac Toe!')

        first_chance = choose_first()

        if(first_chance == 'Player 1'):
            second_chance = 'Player 2'
        else:
            second_chance = 'Player 1'
    
        print('{}, you have the first chance'.format(first_chance))

        order = player_input1(first_chance)

        if(order[0] == 'X'):
            if(first_chance == 'Player 1'):
                p1_marker = 'X'
                p2_marker = 'O'
            else:
                p1_marker = 'X'
                p2_marker = 'O'
        
        else:
            if(first_chance == 'Player 1'):
                p1_marker = 'O'
                p2_marker = 'X'
            else:
                p1_marker = 'O'
                p2_marker = 'X'
        
    
        print('{} marker : '.format(first_chance),p1_marker)
        print('{} marker : '.format(second_chance),p2_marker)

        print('The current board is :')
        display_board(board)

        for num in range(len(board)):
    
            if(num%2==0):
                print('{} Turn'.format(first_chance))
                pos_t = player_ch(board)
                place_marker(board,p1_marker,pos_t)
                if(win_check(board,p1_marker)== 'Win'):
                    print('{} won !!'.format(first_chance))
                    if(replay() == False):
                        rp = False
                        return 'Thanks for playing! :)'
                    else:
                        driver1()
                        
                    
            else:
                print('{} Turn'.format(second_chance))
                pos_t = player_ch(board)
                place_marker(board,p2_marker,pos_t)
                if(win_check(board,p2_marker)== 'Win'):
                    print('{} won !!'.format(second_chance))
                    if(replay() == False):
                        rp = False
                        return 'Thanks for playing! :)'
                    else:
                        driver1()
                            
    else:
        if(full_board_check(board)== True):
            print('Match draw !!')
            if(replay() == False):
                rp = False
                return 'Thanks for playing! :)'
            else:
                driver1()

# %%
driver1()
# Out:
# Welcome to Tic Tac Toe!
# Player 2, you have the first chance
# Player 2 : Do you want to be X or O? x
# Player 2 marker :  X
# Player 1 marker :  O
# The current board is :
#
#      |     |
# -- --|-- --|-- --
#      |     |
# -----|-----|-----
#      |     |
# Player 2 Turn
# Enter the position [1-9]: 5
#
#      |     |
# -- --|-- --|-- --
#      |  X  |
# -----|-----|-----
#      |     |
# Player 1 Turn
# Enter the position [1-9]: 7
#
#   O  |     |
# -- --|-- --|-- --
#      |  X  |
# -----|-----|-----
#      |     |
# Player 2 Turn
# Enter the position [1-9]: 2
#
#   O  |     |
# -- --|-- --|-- --
#      |  X  |
# -----|-----|-----
#      |  X  |
# Player 1 Turn
# Enter the position [1-9]: 8
#
#   O  |  O  |
# -- --|-- --|-- --
#      |  X  |
# -----|-----|-----
#      |  X  |
# Player 2 Turn
# Enter the position [1-9]: 9
#
#   O  |  O  |  X
# -- --|-- --|-- --
#      |  X  |
# -----|-----|-----
#      |  X  |
# Player 1 Turn
# Enter the position [1-9]: 4
#
#   O  |  O  |  X
# ...
